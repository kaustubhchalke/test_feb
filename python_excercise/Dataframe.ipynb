# %%
import pandas as pd

# %%
cd C:\Users\Kaustubh Chalke\Downloads
# Out:
# C:\Users\Kaustubh Chalke\Downloads

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 3089-D320
#
#  Directory of C:\Users\Kaustubh Chalke\Downloads
#
# 02/26/2020  11:53 AM             2,519  BF HW 1.R
# 02/22/2022  01:18 PM    <DIR>          .
# 02/22/2022  01:18 PM    <DIR>          ..
# 05/03/2020  01:43 PM        13,559,675 [BF] Finals.pdf
# 02/21/2022  02:41 PM            27,972 01-SF Salaries Exercise.ipynb
# 04/22/2020  03:51 PM           151,561 1_Ana_Prasanna_Patil_Resume.pdf
# 04/30/2020  04:18 PM           294,503 1-4e31b8b62667dba50386071d8129d0e2.doc
# 09/17/2019  10:30 PM            48,625 1568581921514-6070811733342183471 (1).zip
# 09/16/2019  09:05 PM            48,625 1568581921514-6070811733342183471.zip
# 09/29/2019  11:02 PM           220,346 15698105188919203180271659891815.zip
# 11/19/2019  11:20 PM           265,006 1574052273084-1627656645690529378.zip
# 04/27/2021  04:33 PM        21,132,018 1589997390-BeatsUpdaterInstallerPROD.zip
# ...

# %%
 df=pd.read_csv("Salaries1.csv")

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
#Average base pay
df['BasePay'].mean()
# Out:
# 66325.44884050643

# %%
#Overtime
max(df['OvertimePay'])
# Out:
# 245131.88

# %%
#JOSEPH DRISCOLL
df.loc[df['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
# Out:
#     Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 24  31909.28       NaN  270324.91         270324.91  2011    NaN
#
#            Agency  Status
# 24  San Francisco     NaN

# %%
#JOSEPH DRISCOLL Total pay benefits 
df.loc[df['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
#What is the name of highest paid person (including benefits)?
df.loc[df['TotalPayBenefits']==max(df['TotalPayBenefits'])]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
#Lowest befeits
df.loc[df['TotalPayBenefits']==min(df['TotalPayBenefits'])]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
#average (mean) BasePay of all employees per year? (2011-2014) ?
df.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
#unique job titles
len(set(df['JobTitle']))
# Out:
# 2159

# %%
# top 5 most common jobs
df['JobTitle'].value_counts()[:5]
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
#Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?)
filtered=df[df['Year']==2013]
# print("before",len(filtered['JobTitle']))
d={}
for i in filtered['JobTitle']:
    if d.get(i) is not None:
        d[i]+=1
    else:
        d[i]=1
for key,val in d.items():
    if val==1:
        print(key)
# print("after",len(d
# Out:
# Chief of Police
# Chief, Fire Department
# Dep Dir for Investments, Ret
# Gen Mgr, Public Trnsp Dept
# Mayor
# Adm, SFGH Medical Center
# Controller
# Port Director
# Emergency Medical Svcs Chief
# District Attorney
# City Attorney
# Sheriff (SFERS)
# Administrator, DPH
# Public Defender
# Forensic Toxicologist
# Court Executive Officer
# Human Resources Director
# Dir Emp Relations Div
# Chief Adult Probation Officer
# Special Assistant 21
# Undersheriff
# Assistant Sheriff
# Director, Info Tech Group
# Assistant Inspector
# Treasurer
# Board Scty, MTA
# Wire Rope Cable Maint Sprv
# Managing Attorney
# Assessor
# Chf District Atty Investigator
# Law Librarian
# Chief Dep Adlt Prob Of (SFERS)
# Trnst Power Line Wrk Sprv 2
# Assistant Inspector 2
# Director, Fiscal Services
# Telecommunications Tech Supv
# Asst Chf, Bur Clm Invest&Admin
# Sr Light Rail Veh Equip Eng
# Airport Mechanical Maint Sprv
# Disability Access Coordinator
# Court Reporter Coordinator
# Operating Room Nurse
# ...

# %%
# word Chief in their job title
count=0
for i in df['JobTitle']:
    if 'chief' in i or 'Chief' in i:
        count+=1
print(count)
# Out:
# 423

# %%
nl=[len(x) for x in df['JobTitle']]

# %%
 df['TotalPayBenefits'].corr(df['JobTitle'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-1d0de420672a> in <module>
# ----> 1 df['TotalPayBenefits'].corr(df['JobTitle'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2103         if method in ['pearson', 'spearman', 'kendall'] or callable(method):
#    2104             return nanops.nancorr(this.values, other.values, method=method,
# -> 2105                                   min_periods=min_periods)
#    2106
#    2107         raise ValueError("method must be either 'pearson', "
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      74             try:
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
# ...
